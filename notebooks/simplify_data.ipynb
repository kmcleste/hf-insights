# %%
import os
import pathlib

import pandas as pd

# %%
def create_df() -> pd.DataFrame:
    filepath: pathlib.Path = pathlib.Path(os.getcwd(), "../data", "models.csv")
    return pd.read_csv(filepath_or_buffer=filepath, sep=",")

# %%
df: pd.DataFrame = create_df()
df.head()
# Out:
#    downloads                                 id              lastModified  \
# 0    3325267  google/vit-base-patch16-224-in21k  2023-02-27T15:04:22.000Z
# 1    1603214            YituTech/conv-bert-base  2021-02-24T11:26:14.000Z
# 2     966618                facebook/bart-large  2022-06-03T10:00:20.000Z
# 3     805160              microsoft/wavlm-large  2022-02-02T21:21:50.000Z
# 4     756029     indobenchmark/indobert-base-p1  2021-05-19T20:22:23.000Z
#
#    likes        pipeline_tag  private repoType         author  \
# 0     61  feature-extraction    False    model         google
# 1      4  feature-extraction    False    model       YituTech
# 2    113  feature-extraction    False    model       facebook
# 3     36  feature-extraction    False    model      microsoft
# 4      7  feature-extraction    False    model  indobenchmark
#
#                                           authorData
# 0  {'avatarUrl': 'https://aeiljuispo.cloudimg.io/...
# 1  {'avatarUrl': 'https://www.gravatar.com/avatar...
# 2  {'avatarUrl': 'https://aeiljuispo.cloudimg.io/...
# 3  {'avatarUrl': 'https://aeiljuispo.cloudimg.io/...
# 4  {'avatarUrl': 'https://aeiljuispo.cloudimg.io/...

# %%
df_subset = df.head(100)

# %%
df_subset.head()
# Out:
#    downloads                                 id              lastModified  \
# 0    3325267  google/vit-base-patch16-224-in21k  2023-02-27T15:04:22.000Z
# 1    1603214            YituTech/conv-bert-base  2021-02-24T11:26:14.000Z
# 2     966618                facebook/bart-large  2022-06-03T10:00:20.000Z
# 3     805160              microsoft/wavlm-large  2022-02-02T21:21:50.000Z
# 4     756029     indobenchmark/indobert-base-p1  2021-05-19T20:22:23.000Z
#
#    likes        pipeline_tag  private repoType         author  \
# 0     61  feature-extraction    False    model         google
# 1      4  feature-extraction    False    model       YituTech
# 2    113  feature-extraction    False    model       facebook
# 3     36  feature-extraction    False    model      microsoft
# 4      7  feature-extraction    False    model  indobenchmark
#
#                                           authorData
# 0  {'avatarUrl': 'https://aeiljuispo.cloudimg.io/...
# 1  {'avatarUrl': 'https://www.gravatar.com/avatar...
# 2  {'avatarUrl': 'https://aeiljuispo.cloudimg.io/...
# 3  {'avatarUrl': 'https://aeiljuispo.cloudimg.io/...
# 4  {'avatarUrl': 'https://aeiljuispo.cloudimg.io/...

# %%
df_subset.to_csv('small.csv', index=False)
